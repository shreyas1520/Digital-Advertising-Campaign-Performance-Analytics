# %% [markdown]
# # 01 - Data Understanding & Profiling
#
# ## Project
# Digital Advertising Campaign Performance Analytics
#
# ### Objective
#
# Understand the dataset structure, verify data quality, inspect data types, identify missing values and duplicate records, and assess whether the dataset is suitable for marketing analytics.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Display settings
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("C:/Users/Hp/OneDrive/Desktop/Digital Advertising Campaign Performance Analytics/Data/tech_advertising_campaigns_dataset.csv")

df.head()
# Out:
#   campaign_id campaign_objective    platform ad_placement device_type  \
# 0  CAMP_00001    Lead Generation    Facebook       Search      Mobile
# 1  CAMP_00002         Engagement    Facebook         Feed      Mobile
# 2  CAMP_00003        Conversions  Google Ads         Feed      Tablet
# 3  CAMP_00004        Conversions    LinkedIn       Search     Desktop
# 4  CAMP_00005    Brand Awareness    Facebook      Stories      Mobile
#
#   operating_system creative_format creative_size ad_copy_length  \
# 0          Android            Text        728x90          Short
# 1              iOS           Image        320x50           Long
# 2              iOS           Video     1920x1080          Short
# 3              iOS        Carousel     1920x1080          Short
# 4              iOS           Image     1920x1080          Short
#
#    has_call_to_action creative_emotion  creative_age_days target_audience_age  \
# ...

# %%
df.tail()
# Out:
#      campaign_id campaign_objective    platform ad_placement device_type  \
# 9995  CAMP_09996       App Installs     Twitter      Sidebar      Mobile
# 9996  CAMP_09997       App Installs  Google Ads       Search      Mobile
# 9997  CAMP_09998         Engagement    Facebook         Feed     Desktop
# 9998  CAMP_09999    Lead Generation    Facebook      Stories      Mobile
# 9999  CAMP_10000    Lead Generation  Google Ads         Feed      Mobile
#
#      operating_system creative_format creative_size ad_copy_length  \
# 9995          Windows           Story       300x250          Short
# 9996              iOS           Image        320x50          Short
# 9997          Windows           Image        320x50          Short
# 9998          Android           Image     1080x1080          Short
# 9999            macOS           Image     1080x1080           Long
#
#       has_call_to_action creative_emotion  creative_age_days  \
# ...

# %%
rows, cols = df.shape

print("Number of Rows:", rows)
print("Number of Columns:", cols)
# Out:
# Number of Rows: 10000
# Number of Columns: 41

# %%
df.sample(5, random_state=42)
# Out:
#      campaign_id campaign_objective    platform ad_placement device_type  \
# 6252  CAMP_06253    Lead Generation  Google Ads      Sidebar      Mobile
# 4684  CAMP_04685        Conversions      TikTok         Feed      Mobile
# 1731  CAMP_01732        Conversions  Google Ads      Sidebar      Mobile
# 4742  CAMP_04743    Brand Awareness      TikTok         Feed     Desktop
# 4521  CAMP_04522        Conversions   Instagram      Stories      Mobile
#
#      operating_system creative_format creative_size ad_copy_length  \
# 6252          Windows           Image     1920x1080         Medium
# 4684          Android            Text        728x90           Long
# 1731              iOS           Video     1080x1080           Long
# 4742          Windows        Carousel       300x250           Long
# 4521          Windows     Interactive       300x250          Short
#
#       has_call_to_action creative_emotion  creative_age_days  \
# ...

# %% [markdown]
# # Business Understanding
#
# ## Objective
#
# Analyze digital advertising campaign performance to identify
# high-performing campaigns, optimize advertising spend,
# improve conversion rates, and maximize Return on Ad Spend (ROAS).
#
# ## Business Questions
#
# - Which campaigns generate the highest ROI?
# - Which platform performs best?
# - Which audience converts the most?
# - Which device has the highest engagement?
# - Which campaigns require optimization?

# %%
df.shape
# Out:
# (10000, 41)

# %%
df.columns.tolist()
# Out:
# ['campaign_id',
#  'campaign_objective',
#  'platform',
#  'ad_placement',
#  'device_type',
#  'operating_system',
#  'creative_format',
#  'creative_size',
#  'ad_copy_length',
#  'has_call_to_action',
#  'creative_emotion',
#  'creative_age_days',
#  'target_audience_age',
#  'target_audience_gender',
#  'audience_interest_category',
#  'income_bracket',
#  'purchase_intent_score',
#  'retargeting_flag',
#  'start_date',
#  'quarter',
#  'day_of_week',
#  'hour_of_day',
#  'campaign_day',
#  'quality_score',
#  'actual_cpc',
#  'impressions',
#  'clicks',
#  'conversions',
#  'ad_spend',
#  'revenue',
#  'bounce_rate',
#  'avg_session_duration_seconds',
#  'pages_per_session',
#  'industry_vertical',
#  'budget_tier',
#  'CTR',
#  'CPC',
#  'conversion_rate',
#  'CPA',
#  'ROAS',
#  'profit']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   campaign_id                   10000 non-null  str
#  1   campaign_objective            10000 non-null  str
#  2   platform                      10000 non-null  str
#  3   ad_placement                  10000 non-null  str
#  4   device_type                   10000 non-null  str
#  5   operating_system              10000 non-null  str
#  6   creative_format               10000 non-null  str
#  7   creative_size                 10000 non-null  str
#  8   ad_copy_length                10000 non-null  str
#  9   has_call_to_action            10000 non-null  bool
#  10  creative_emotion              10000 non-null  str
#  11  creative_age_days             10000 non-null  int64
#  12  target_audience_age           10000 non-null  str
# ...

# %%
df.describe().T
# Out:
#                                 count          mean           std       min  \
# creative_age_days             10000.0     45.374300     26.171100      1.00
# quarter                       10000.0      2.419100      1.132424      1.00
# hour_of_day                   10000.0     11.482500      6.932308      0.00
# campaign_day                  10000.0     45.429700     26.071107      1.00
# quality_score                 10000.0      5.527400      1.553541      1.00
# actual_cpc                    10000.0      3.290336      2.453852      0.30
# impressions                   10000.0  70539.223000  91339.733246   5000.00
# clicks                        10000.0   1526.436100   2412.164582     10.00
# conversions                   10000.0     65.568800    183.404876      0.00
# ad_spend                      10000.0   4345.566179   6917.481037      8.69
# revenue                       10000.0  28415.770647  89284.609131      0.00
# ...

# %%
df.isnull().sum()
# Out:
# campaign_id                     0
# campaign_objective              0
# platform                        0
# ad_placement                    0
# device_type                     0
# operating_system                0
# creative_format                 0
# creative_size                   0
# ad_copy_length                  0
# has_call_to_action              0
# creative_emotion                0
# creative_age_days               0
# target_audience_age             0
# target_audience_gender          0
# audience_interest_category      0
# income_bracket                  0
# purchase_intent_score           0
# retargeting_flag                0
# start_date                      0
# quarter                         0
# day_of_week                     0
# hour_of_day                     0
# campaign_day                    0
# quality_score                   0
# actual_cpc                      0
# impressions                     0
# clicks                          0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# campaign_id                         str
# campaign_objective                  str
# platform                            str
# ad_placement                        str
# device_type                         str
# operating_system                    str
# creative_format                     str
# creative_size                       str
# ad_copy_length                      str
# has_call_to_action                 bool
# creative_emotion                    str
# creative_age_days                 int64
# target_audience_age                 str
# target_audience_gender              str
# audience_interest_category          str
# income_bracket                      str
# purchase_intent_score               str
# retargeting_flag                   bool
# start_date                          str
# quarter                           int64
# day_of_week                         str
# hour_of_day                       int64
# campaign_day                      int64
# ...

# %%
categorical_columns = df.select_dtypes(include='object').columns

for col in categorical_columns:
    print(f"{col}: {df[col].nunique()} unique values")
# Out:
# campaign_id: 10000 unique values
# campaign_objective: 5 unique values
# platform: 6 unique values
# ad_placement: 6 unique values
# device_type: 3 unique values
# operating_system: 5 unique values
# creative_format: 6 unique values
# creative_size: 6 unique values
# ad_copy_length: 3 unique values
# creative_emotion: 6 unique values
# target_audience_age: 6 unique values
# target_audience_gender: 3 unique values
# audience_interest_category: 6 unique values
# income_bracket: 4 unique values
# purchase_intent_score: 3 unique values
# start_date: 761 unique values
# day_of_week: 7 unique values
# industry_vertical: 6 unique values
# budget_tier: 3 unique values
# ...

# %%
numerical_columns = df.select_dtypes(include=np.number).columns

categorical_columns = df.select_dtypes(exclude=np.number).columns

print("Numerical Columns:", len(numerical_columns))
print("Categorical Columns:", len(categorical_columns))
# Out:
# Numerical Columns: 20
# Categorical Columns: 21

# %%
df.memory_usage(deep=True)
# Out:
# Index                              132
# campaign_id                     590000
# campaign_objective              622468
# platform                        573241
# ad_placement                    563084
# device_type                     553556
# operating_system                545840
# creative_format                 548056
# creative_size                   567840
# ad_copy_length                  542088
# has_call_to_action               10000
# creative_emotion                545692
# creative_age_days                80000
# target_audience_age             539206
# target_audience_gender          534123
# audience_interest_category      628076
# income_bracket                  576009
# purchase_intent_score           536006
# retargeting_flag                 10000
# start_date                      590000
# quarter                          80000
# day_of_week                     561512
# hour_of_day                      80000
# campaign_day                     80000
# ...

# %%
df.memory_usage(deep=True).sum() / 1024**2
# Out:
# np.float64(11.768513679504395)

# %% [markdown]
# # Initial Findings
#
# - Dataset contains 10,000 campaign records.
# - Contains 41 variables.
# - Missing values: 0
# - Duplicate records: 0
# - Dataset appears suitable for marketing analytics.
# - Multiple campaign platforms are available.
# - Includes financial KPIs such as ROAS, CPC, CPA, Revenue and Profit.

# %% [markdown]
# # Conclusion
#
# The dataset has been successfully profiled and validated.
#
# ### Key Observations
#
# - The dataset contains 10,000 campaign records across 41 variables.
# - No missing values were identified.
# - No duplicate records were found.
# - Numerical and categorical variables are well structured.
# - The dataset includes campaign, customer, financial, and engagement metrics.
# - Overall, the dataset is suitable for marketing analytics and business intelligence reporting.
#
# The next step is Data Cleaning & Preprocessing to validate data consistency and prepare the dataset for exploratory analysis.
